# %%
import graphviz

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Pulin\Desktop\GLS_greenbubble

# %%
import os

# Add your Conda environment Graphviz bin folder to PATH
os.environ["PATH"] += r";C:\Users\Pulin\anaconda3\envs\pypsa1\Graphviz\bin"

from graphviz import Source

# Then your normal code
dot_path = r"outputs\single_analysis\SB_H2_meoh_SN_CO2c150_H2d272_MeOHd120_CH4d438_2024_ElDK1_0.1_singles_biogas\networks\SB_H2_meoh_SN_CO2c150_H2d272_MeOHd120_CH4d438_2024_ElDK1_0.1_singles_biogas_OPT.dot"

with open(dot_path) as f:
    dot_source = f.read()

graph = Source(dot_source, format="svg")
svg_path = graph.render("network_graph", cleanup=True)

print("SVG saved to:", svg_path)
# Out:
# SVG saved to: network_graph.svg
